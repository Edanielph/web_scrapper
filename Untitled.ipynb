# %%
import pandas as pd
series_test = pd.Series([100, 200, 300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
clean_eluniversal = pd.read_csv('C:/Users/danyp_000/Documents/GitHub/web_scrapper/eluniversal.csv')

# %%
clean_eluniversal.describe()
# Out:
#                                                      body  \
# count                                                 102
# unique                                                102
# top     \nDirigentes y diputados del PRD presentaron a...
# freq                                                    1
#
#                                                     title  \
# count                                                  81
# unique                                                 81
# top     Los autos de Michael Jordan que aparecen en su...
# freq                                                    1
#
#                                                       url
# count                                                 102
# unique                                                102
# top     https://www.eluniversal.com.mx/universal-depor...
# freq                                                    1

# %%
clean_eluniversal = pd.read_csv('C:/Users/danyp_000/Documents/GitHub/web_scrapper/eluniversal.csv')

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\danyp_000\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
clean_eluniversal = pd.read_csv('C:/Users/danyp_000/Documents/GitHub/web_scrapper/eluniversal.csv')

# %%
el_universal = pd.read_csv('C:/Users/danyp_000/Documents/GitHub/web_scrapper/eluniversal.csv')
el_universal
# Out:
#                                                   body  \
# 0     0 % PULSO SOCIAL0 Mientras el número de conta...
# 1    \nLa pandemia de Covid-19 ya ha contagiado a m...
# 2    \nLa reciente fórmula que estableció ESPN para...
# 3    \nChina elevó este domingo el nivel de riesgo ...
# 4    \nEl vicepresidente de Estados Unidos, Mike Pe...
# ..                                                 ...
# 97   \nAmaury Vergara, presidente del Guadalajara, ...
# 98   A unas horas del Día de las Madres, en lugar d...
# 99   \nLa corista Mollie Gould presumió sus dotes d...
# 100  \nSalma Hayek publicó una selfie en redes soci...
# 101  \nNos hacen ver que algunos de los opositores ...
#
#                                                  title  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ESPN cambia a sus comentaristas de Monday Nigh...
# 3    Regresa Covid-19 a Wuhan; detectan un caso nue...
# ...

# %%
el_universal['title']
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2      ESPN cambia a sus comentaristas de Monday Nigh...
# 3      Regresa Covid-19 a Wuhan; detectan un caso nue...
# 4      Vicepresidente de EU se aisla tras positivo de...
#                              ...
# 97               Chivas estrenará su serie de televisión
# 98                                                   NaN
# 99                                                   NaN
# 100                                                  NaN
# 101                      Los orgullosos aliados de la 4T
# Name: title, Length: 102, dtype: object

# %%
el_universal[['title','url']]
# Out:
#                                                  title  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ESPN cambia a sus comentaristas de Monday Nigh...
# 3    Regresa Covid-19 a Wuhan; detectan un caso nue...
# 4    Vicepresidente de EU se aisla tras positivo de...
# ..                                                 ...
# 97             Chivas estrenará su serie de televisión
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                    Los orgullosos aliados de la 4T
#
#                                                    url
# 0    https://de10.com.mx/cultura-digital/en-china-u...
# 1    https://www.viveusa.mx/bienestar/que-es-la-inm...
# 2    https://www.eluniversal.com.mx/universal-depor...
# 3    https://www.eluniversal.com.mx/mundo/regresa-c...
# ...

# %%
el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10  \nLa doctora Beatriz Gutiérrez Müller, esposa ...
# 11  \nEl luchador mexicano y ex gladiador de la WW...
# 12  \n\nLeón, Guanajuato.- A Sara le apasiona ser ...
# 13  \nUn total de 300 trabajadores temporales, que...
# 14  \nUn presunto integrante de la delincuencia or...
#
#                                                 title  \
# 10  Gutiérrez Müller dedica celebración a madres m...
# 11     Detienen a Alberto del Río por agresión sexual
# 12  Dedica Día de las Madres a atender pacientes C...
# 13  Ciudadanos contratados durante pandemia ya tra...
# 14  Detienen a hombre con rifle de asalto con incr...
#
#                                                   url
# 10  https://www.eluniversal.com.mx/nacion/dia-de-l...
# 11  https://www.eluniversal.com.mx/universal-depor...
# 12  https://www.eluniversal.com.mx/estados/dedica-...
# 13  https://sanluis.eluniversal.com.mx/metropoli/2...
# ...

# %%
el_universal.iloc[66]['title']
# Out:
# 'Arman fiesta con banda y golpean a funcionarios que intentaron cancelar festejo en Ecatepec'

# %%
el_universal.iloc[:5, 0]
# Out:
# 0     0 % PULSO SOCIAL0 Mientras el número de conta...
# 1    \nLa pandemia de Covid-19 ya ha contagiado a m...
# 2    \nLa reciente fórmula que estableció ESPN para...
# 3    \nChina elevó este domingo el nivel de riesgo ...
# 4    \nEl vicepresidente de Estados Unidos, Mike Pe...
# Name: body, dtype: object

# %%
el_universal.loc[:,'body':'title']
# Out:
#                                                   body  \
# 0     0 % PULSO SOCIAL0 Mientras el número de conta...
# 1    \nLa pandemia de Covid-19 ya ha contagiado a m...
# 2    \nLa reciente fórmula que estableció ESPN para...
# 3    \nChina elevó este domingo el nivel de riesgo ...
# 4    \nEl vicepresidente de Estados Unidos, Mike Pe...
# ..                                                 ...
# 97   \nAmaury Vergara, presidente del Guadalajara, ...
# 98   A unas horas del Día de las Madres, en lugar d...
# 99   \nLa corista Mollie Gould presumió sus dotes d...
# 100  \nSalma Hayek publicó una selfie en redes soci...
# 101  \nNos hacen ver que algunos de los opositores ...
#
#                                                  title
# 0                                                  NaN
# 1                                                  NaN
# 2    ESPN cambia a sus comentaristas de Monday Nigh...
# 3    Regresa Covid-19 a Wuhan; detectan un caso nue...
# ...

# %%
el_universal['newspaper_uid'] = 'eluniversal'
el_universal
# Out:
#                                                   body  \
# 0     0 % PULSO SOCIAL0 Mientras el número de conta...
# 1    \nLa pandemia de Covid-19 ya ha contagiado a m...
# 2    \nLa reciente fórmula que estableció ESPN para...
# 3    \nChina elevó este domingo el nivel de riesgo ...
# 4    \nEl vicepresidente de Estados Unidos, Mike Pe...
# ..                                                 ...
# 97   \nAmaury Vergara, presidente del Guadalajara, ...
# 98   A unas horas del Día de las Madres, en lugar d...
# 99   \nLa corista Mollie Gould presumió sus dotes d...
# 100  \nSalma Hayek publicó una selfie en redes soci...
# 101  \nNos hacen ver que algunos de los opositores ...
#
#                                                  title  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ESPN cambia a sus comentaristas de Monday Nigh...
# 3    Regresa Covid-19 a Wuhan; detectan un caso nue...
# ...

# %%
#2. Obtener el host
from urllib.parse import urlparse
el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)
el_universal
# Out:
#                                                   body  \
# 0     0 % PULSO SOCIAL0 Mientras el número de conta...
# 1    \nLa pandemia de Covid-19 ya ha contagiado a m...
# 2    \nLa reciente fórmula que estableció ESPN para...
# 3    \nChina elevó este domingo el nivel de riesgo ...
# 4    \nEl vicepresidente de Estados Unidos, Mike Pe...
# ..                                                 ...
# 97   \nAmaury Vergara, presidente del Guadalajara, ...
# 98   A unas horas del Día de las Madres, en lugar d...
# 99   \nLa corista Mollie Gould presumió sus dotes d...
# 100  \nSalma Hayek publicó una selfie en redes soci...
# 101  \nNos hacen ver que algunos de los opositores ...
#
#                                                  title  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ESPN cambia a sus comentaristas de Monday Nigh...
# 3    Regresa Covid-19 a Wuhan; detectan un caso nue...
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx         69
# www.viveusa.mx                 14
# de10.com.mx                     6
# www.eluniversalqueretaro.mx     5
# oaxaca.eluniversal.com.mx       4
# sanluis.eluniversal.com.mx      3
# www.elgrafico.mx                1
# Name: host, dtype: int64

# %%
#8. Eliminar duplicados
el_universal['title'].value_counts()
# Out:
# Los autos de Michael Jordan que aparecen en su serie                      1
# Cinco estados tratan con plasma a pacientes Covid-19                      1
# Vicepresidente de EU se aisla tras positivo de Covid-19 de su portavoz    1
# ¿Por qué los trabajadores destruían las máquinas?                         1
# Dan de alta a paciente con Covid-19 tratado con plasma en Nuevo León      1
#                                                                          ..
# Tiendas Elektra encuentra su metáfora en Bérgamo                          1
# Adiós a la voz de Héctor Martínez Serrano, figura de la radio mexicana    1
# Deliciosos postres para prepararle a mamá en su día                       1
# El día que Michael Jordan sufrió contra la Selección Mexicana             1
# "Miguel Herrera merece dirigir en Europa", Pedro Caixinha                 1
# Name: title, Length: 81, dtype: int64

# %%
el_universal[el_universal['title'] == 'La nostalgia del calderonismo']
# Out:
#                                                  body  \
# 79  \n\nEl expresidente Felipe Calderón y varios d...
#
#                             title  \
# 79  La nostalgia del calderonismo
#
#                                                   url newspaper_uid  \
# 79  https://www.eluniversal.com.mx/opinion/periodi...   eluniversal
#
#                       host
# 79  www.eluniversal.com.mx

# %%
import nltk
from nltk.corpus import stopwords

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    n_tokens = (df
                 .dropna()
                 .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
                 .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                 .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
                 .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
                 .apply(lambda valid_word_list: len(valid_word_list))       
                )
el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
el_universal
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-40-e4b488b9f215> in <module>
#      13                  .apply(lambda valid_word_list: len(valid_word_list))
#      14                 )
# ---> 15 el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
#      16 el_universal
#
# <ipython-input-40-e4b488b9f215> in tokenize_column(df, column_name)
#       5
#       6 def tokenize_column(df, column_name):
# ----> 7     n_tokens = (df
#       8                  .dropna()
#       9                  .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ...

# %%
clean_eluniversal = pd.read_csv('C:/Users/danyp_000/Documents/GitHub/web_scrapper/eluniversal.csv')

# %%
clean_eluniversal.describe()
# Out:
#                                                      body  \
# count                                                 102
# unique                                                102
# top     \nDirigentes y diputados del PRD presentaron a...
# freq                                                    1
#
#                                                     title  \
# count                                                  81
# unique                                                 81
# top     Los autos de Michael Jordan que aparecen en su...
# freq                                                    1
#
#                                                       url
# count                                                 102
# unique                                                102
# top     https://www.eluniversal.com.mx/universal-depor...
# freq                                                    1

# %%
clean_eluniversal.loc[clean_eluniversal['n_tokens_title'] == 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n_tokens_title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-75bb793eb6c5> in <module>
# ...

# %%
# %matplotlib inline

# %%
clean_eluniversal['n_tokens'].plot(style='r.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n_tokens'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-3818c9cebd58> in <module>
# ...

# %%
clean_eluniversal['n_tokens_title'].plot(style='r.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'n_tokens_title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-951eb446fd61> in <module>
# ...
